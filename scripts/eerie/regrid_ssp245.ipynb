# %%
import os
os.environ["NUMBA_NUM_THREADS"] = "64"

import importlib
import requests
import xarray as xr
import remap_numba_helpers as rnh
import remap_zarr_helpers as rzh

importlib.reload(rnh)
importlib.reload(rzh)

import xarray as xr
import requests
item=requests.get("https://stac2.cloud.dkrz.de/fastapi/collections/eerie-eerie-mpi-m-icon-esm-er-highres-future-ssp245-v20240618/items/eerie-eerie-mpi-m-icon-esm-er-highres-future-ssp245-v20240618-disk.model-output.icon-esm-er.highres-future-ssp245.v20240618.atmos.native.2d_monthly_mean-zarr-kerchunk").json()
asset="dkrz-disk"
data = xr.open_dataset(
    item["assets"][asset]["href"],
    **item["assets"][asset]["xarray:open_kwargs"],
    storage_options=item["assets"][asset].get("xarray:storage_options")
)
#data
prepared_max, store_paths = rzh.remap_variables_to_all_zoom_stores(
    source_ds=data,
    variables=["ts","pr"],
    zooms=[9],
    dataset_id="eerie-future-ssp245-v20240618",
    frequency_tag="P1M",
    stat_tag="mean",
    out_root="/scratch/k/k202181/remap_eerie/eerie-future-ssp245-v20240618",
    cache_root="/scratch/k/k202181/remap_eerie",
    gridfile="/pool/data/ICON/grids/public/mpim/0033/icon_grid_0033_R02B08_G.nc",
    rnh_module=rnh,
    cell_chunk=65536,
    pyramid_agg="nanmean",
    min_zoom=0,
    nest=True,
    use_memmap=False,
    show_progress=True,
    verbose=True,
    rebuild_source_cache=False,
    rebuild_target_cache=False,
    rebuild_weights=False,
    resume=True,
    overwrite_variables=True,
    check_conservation_first_step=False,
    consolidate_at_end=True,
)
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='f04f49b4-a750-48a3-8cdf-5c5804e1a1b1'>
#   <div id="b18c0edf-78bb-4f77-a856-7639ba9dd0bc" data-root-id="f04f49b4-a750-48a3-8cdf-5c5804e1a1b1" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"a5f8a438-81a2-4c78-a7cc-ac60051d9a9b":{"version":"3.9.0","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"c8cebd81-284f-4686-9bfd-65494d5d14b8","attributes":{"notifications":{"type":"object","name":"Notifications","id":"1b44feb6-a9cc-4a3f-9d88-4e8b948b4286"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"f04f49b4-a750-48a3-8cdf-5c5804e1a1b1"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"cbb5b62d-5c8c-4201-a2d8-0d971b2d2fe0","attributes":{"plot_id":"f04f49b4-a750-48a3-8cdf-5c5804e1a1b1","comm_id":"c26d3b9023a440beb68d464f17f81c4b","client_comm_id":"df8e6fcdd8554da8ac21c01b4a158392"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"a5f8a438-81a2-4c78-a7cc-ac60051d9a9b","roots":{"f04f49b4-a750-48a3-8cdf-5c5804e1a1b1":"b18c0edf-78bb-4f77-a856-7639ba9dd0bc"},"root_ids":["f04f49b4-a750-48a3-8cdf-5c5804e1a1b1"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# === PREPARE MAX ZOOM 9 ===
# [start] load/build source grid
# [done ] load/build source grid: 0.00s
# [start] hash source grid
# [done ] hash source grid: 7.46s
# [start] load/build native source cache
# [done ] load/build native source cache: 0.79s
# [start] build source mesh
# [done ] build source mesh: 28.10s
# [start] build target grid
# [done ] build target grid: 2.79s
# [start] hash target grid
# [done ] hash target grid: 0.45s
# [start] load/build target cache
# target cache: 100%|██████████| 2/2 [00:09<00:00,  4.60s/it]
# target cache written: /scratch/k/k202181/remap_eerie/target/fad4ac99540fca745befdc985ef7d38d2d52ce59
# {
#   "n_face_full": 3145728,
#   "n_face_kept": 3145728,
#   "n_node_all": 3145730,
#   "n_bad_faces_skipped": 0
# }
# [done ] load/build target cache: 9.58s
# [start] hash grid pair
# [done ] hash grid pair: 0.00s
# [start] build target mesh
# [done ] build target mesh: 25.25s
# [start] build fields
# [done ] build fields: 2.48s
# [start] build/load regrid operator
# building new weights: /scratch/k/k202181/remap_eerie/weights/1a4cecf55df3700530dd13ccfeb0ba07ac500d1b.nc
# [done ] build/load regrid operator: 236.67s
#
# Prepare timings:
#   load/build source grid               0.00s
#   hash source grid                     7.46s
#   load/build native source cache       0.79s
#   build source mesh                   28.10s
#   build target grid                    2.79s
#   hash target grid                     0.45s
#   load/build target cache              9.58s
#   hash grid pair                       0.00s
#   build target mesh                   25.25s
#   build fields                         2.48s
#   build/load regrid operator         236.67s
#   src_grid_hash        : 1ccf59315edd434e06fc6fef239deceb47c85e80
#   dst_grid_hash        : fad4ac99540fca745befdc985ef7d38d2d52ce59  (stable HEALPix spec hash)
#   dst_grid_geom_hash   : 2133cadcfbf2bda06916c960684377563affb140  (debug only)
#   pair_hash            : 1a4cecf55df3700530dd13ccfeb0ba07ac500d1b
#
# === REMAP ts TO PYRAMID 9->0 ===
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: start at timestep 0/432
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: output dtype = float32, chunks=(1, 65536), pyramid=9->0, agg=nanmean
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 1/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 2/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 3/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 4/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 5/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 6/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 7/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 8/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 9/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 10/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 11/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 12/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 13/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 14/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 15/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 16/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 17/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 18/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 19/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 20/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 21/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 22/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 23/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 24/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 25/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 26/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 27/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 28/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 29/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 30/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 31/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 32/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 33/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 34/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 35/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 36/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 37/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 38/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 39/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 40/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 41/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 42/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 43/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 44/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 45/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 46/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 47/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 48/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 49/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 50/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 51/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 52/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 53/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 54/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 55/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 56/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 57/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 58/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 59/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 60/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 61/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 62/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 63/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 64/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 65/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 66/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 67/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 68/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 69/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 70/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 71/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 72/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 73/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 74/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 75/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 76/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 77/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 78/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 79/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 80/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 81/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 82/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 83/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 84/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 85/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 86/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 87/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 88/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 89/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 90/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 91/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 92/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 93/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 94/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 95/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 96/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 97/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 98/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 99/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 100/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 101/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 102/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 103/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 104/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 105/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 106/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 107/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 108/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 109/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 110/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 111/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 112/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 113/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 114/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 115/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 116/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 117/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 118/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 119/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 120/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 121/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 122/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 123/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 124/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 125/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 126/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 127/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 128/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 129/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 130/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 131/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 132/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 133/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 134/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 135/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 136/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 137/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 138/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 139/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 140/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 141/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 142/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 143/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 144/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 145/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 146/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 147/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 148/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 149/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 150/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 151/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 152/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 153/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 154/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 155/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 156/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 157/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 158/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 159/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 160/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 161/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 162/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 163/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 164/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 165/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 166/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 167/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 168/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 169/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 170/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 171/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 172/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 173/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 174/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 175/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 176/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 177/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 178/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 179/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 180/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 181/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 182/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 183/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 184/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 185/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 186/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 187/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 188/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 189/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 190/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 191/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 192/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 193/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 194/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 195/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 196/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 197/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 198/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 199/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 200/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 201/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 202/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 203/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 204/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 205/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 206/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 207/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 208/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 209/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 210/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 211/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 212/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 213/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 214/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 215/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 216/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 217/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 218/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 219/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 220/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 221/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 222/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 223/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 224/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 225/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 226/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 227/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 228/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 229/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 230/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 231/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 232/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 233/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 234/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 235/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 236/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 237/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 238/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 239/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 240/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 241/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 242/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 243/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 244/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 245/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 246/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 247/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 248/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 249/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 250/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 251/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 252/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 253/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 254/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 255/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 256/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 257/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 258/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 259/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 260/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 261/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 262/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 263/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 264/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 265/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 266/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 267/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 268/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 269/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 270/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 271/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 272/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 273/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 274/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 275/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 276/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 277/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 278/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote 279/432 to zooms 9->0
# eerie-future-ssp245-v20240618_P1M_mean_9.zarr :: ts: wrote